# %% [markdown]
# # Spatial Iteration Engine — Control completo en notebook
#
# Este notebook **genera el engine** y muestra **todo** en una sola sesión:
#
# 1. **Preview** — La cámara se ve en un widget de imagen debajo; no hace falta ventana de escritorio.
# 2. **Panel de control** — Pestañas: **Red**, **Engine** (Start/Stop, cámara), **Filtros** (Edges, Invert, Invert C++, etc.), **ASCII/RAW**, **IA** (detección cara/manos/pose, overlay landmarks).
# 3. **Diagnóstico** — Dispositivos de video, latencia y benchmarking.
#
# **Requisitos:** Jupyter desde la raíz del repo; `pip install ipywidgets`. Para IA (percepción): `bash cpp/build.sh` y `PYTHONPATH=python:cpp/build`.

# %%
import os
import sys

# Raíz del repo (ajusta si ejecutas desde otra ruta)
REPO_ROOT = "/home/fissure/repos/Spatial-Iteration-Engine"
os.chdir(REPO_ROOT)
if REPO_ROOT not in sys.path:
    sys.path.insert(0, os.path.join(REPO_ROOT, "python"))

print("Repo:", os.getcwd())
# Out:
# Repo: /home/fissure/repos/Spatial-Iteration-Engine

# %%
from python.ascii_stream_engine import (
    build_engine_for_notebook,
    build_general_control_panel,
    build_diagnostics_panel,
)

# Cámara 0; la imagen aparece debajo al pulsar Start
engine = build_engine_for_notebook(camera_index=2)

print("Engine creado. Usa el panel de abajo: pestaña Engine → Start.")
# Out:
# HTML(value='<b>Preview (la imagen aparece al pulsar Start)</b>')
# Image(value=b'', format='jpeg')
# Engine creado. Usa el panel de abajo: pestaña Engine → Start.

# %%
# Panel completo: Red, Engine, Filtros, ASCII/RAW, IA
build_general_control_panel(engine)
# Out:
# HTML(value='<b>Estado</b>')
# HTML(value='<div style="padding:8px 10px; background:#e7f1ff; border-radius:6px; margin:6px 0; border:1px soli…
# HTML(value='<b>Controles</b>')
# Tab(children=(VBox(children=(HTML(value='<b>Servidor en red</b>'), HTML(value='<small>Local = 127.0.0.1 · Broa…
# {'tabs': Tab(children=(VBox(children=(HTML(value='<b>Servidor en red</b>'), HTML(value='<small>Local = 127.0.0.1 · Broadcast/Multicast para UDP.</small>'), Dropdown(description='Modo red', options=('Local', 'Broadcast', 'Multicast', 'IP directa'), style=DescriptionStyle(description_width='80px'), value='Local'), HBox(children=(Text(value='127.0.0.1', description='Host', style=TextStyle(description_width='80px')), IntText(value=1234, description='Puerto', style=DescriptionStyle(description_width='80px')))), Button(description='Aplicar red', layout=Layout(width='120px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Motor</b>'), HTML(value='<small>Inicia para ver el preview en la celda de arriba.</small>'), HBox(children=(Button(description='▶ Iniciar', layout=Layout(width='100px'), style=ButtonStyle()), Button(description='■ Detener', layout=Layout(width='100px'), style=ButtonStyle()))), HTML(value='<b>Cámara</b>'), HBox(children=(IntText(value=0, description='Cámara', style=DescriptionStyle(description_width='80px')), Button(description='Aplicar cámara', layout=Layout(width='130px'), style=ButtonStyle())))), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Filtros de imagen</b>'), HTML(value='<small>Se aplican antes del render (ASCII/RAW). Puedes combinar varios.</small>'), HBox(children=(Checkbox(value=False, description='Edges'), Checkbox(value=False, description='Brightness/Contrast'), Checkbox(value=False, description='Invert'))), HBox(children=(Checkbox(value=False, description='Invert (C++)'), Checkbox(value=False, description='Detail Boost'))), Button(description='Quitar todos', layout=Layout(width='120px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Vista (ASCII / RAW)</b>'), HTML(value='<small>Video</small>'), IntSlider(value=20, description='FPS', max=60, min=10), HBox(children=(IntSlider(value=120, description='Grid W', max=200, min=60), IntSlider(value=60, description='Grid H', max=120, min=20))), HTML(value='<small>Apariencia</small>'), Dropdown(description='Charset', index=1, options={'Simple': ' .:-=+*#', 'Medio': ' .:-=+*#%@', 'Denso': ' .\'`^\\",:;Il!i~+_-?][}{1)(|\\\\/tfjrxnuvczXYUJCLQ0OZmwqpdbkhao*#MW&8%B@$'}, value=' .:-=+*#%@'), HBox(children=(FloatSlider(value=1.2, description='Contraste', max=3.0, min=0.5), IntSlider(value=0, description='Brillo', max=50, min=-50))), RadioButtons(description='Modo', options=(('ASCII', 'ascii'), ('RAW (sin ASCII)', 'raw')), value='ascii'), HTML(value='<small>RAW (tamaño)</small>'), HBox(children=(Checkbox(value=False, description='Usar tamano RAW'), IntText(value=640, description='Raw W'), IntText(value=360, description='Raw H'))), HBox(children=(IntSlider(value=2, description='Buffer', max=3), Text(value='1500k', description='Bitrate'))), Button(description='Aplicar ajustes', layout=Layout(width='140px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Percepción (IA)</b>'), HTML(value='<div style="padding:6px; background:#f8f9fa; border-radius:4px; font-size:12px;">1) Activa cara/manos/pose · 2) Elige Overlay landmarks · 3) Aplicar IA · 4) Inicia el motor.</div>'), HBox(children=(Checkbox(value=False, description='Detección cara (face)'), Checkbox(value=False, description='Detección manos (hands)'), Checkbox(value=False, description='Detección pose (pose)'))), Dropdown(description='Visualización', options=('Normal (según ASCII/RAW)', 'Overlay landmarks'), value='Normal (según ASCII/RAW)'), Button(description='Aplicar IA', layout=Layout(width='120px'), style=ButtonStyle()), HTML(value='<b>Estado del detector</b>'), HTML(value='<i>Estado: — Pulsa «Actualizar estado detector» con el engine en marcha.</i>'), Button(description='Actualizar estado detector', layout=Layout(width='200px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0'))), selected_index=0, titles=('Red', 'Motor', 'Filtros', 'Vista', 'IA')),
#  'network': {'mode': Dropdown(description='Modo red', options=('Local', 'Broadcast', 'Multicast', 'IP directa'), style=DescriptionStyle(description_width='80px'), value='Local'),
#   'host': Text(value='127.0.0.1', description='Host', style=TextStyle(description_width='80px')),
#   'port': IntText(value=1234, description='Puerto', style=DescriptionStyle(description_width='80px')),
#   'apply': Button(description='Aplicar red', layout=Layout(width='120px'), style=ButtonStyle())},
#  'engine': {'start': Button(description='▶ Iniciar', layout=Layout(width='100px'), style=ButtonStyle()),
#   'stop': Button(description='■ Detener', layout=Layout(width='100px'), style=ButtonStyle()),
#   'camera_index': IntText(value=0, description='Cámara', style=DescriptionStyle(description_width='80px')),
#   'apply_camera': Button(description='Aplicar cámara', layout=Layout(width='130px'), style=ButtonStyle())},
#  'filters': {'Edges': Checkbox(value=False, description='Edges'),
#   'Brightness/Contrast': Checkbox(value=False, description='Brightness/Contrast'),
#   'Invert': Checkbox(value=False, description='Invert'),
#   'Invert (C++)': Checkbox(value=False, description='Invert (C++)'),
#   'Detail Boost': Checkbox(value=False, description='Detail Boost')},
#  'ascii': {'fps': IntSlider(value=20, description='FPS', max=60, min=10),
#   'grid_w': IntSlider(value=120, description='Grid W', max=200, min=60),
#   'grid_h': IntSlider(value=60, description='Grid H', max=120, min=20),
#   'charset': Dropdown(description='Charset', index=1, options={'Simple': ' .:-=+*#', 'Medio': ' .:-=+*#%@', 'Denso': ' .\'`^\\",:;Il!i~+_-?][}{1)(|\\\\/tfjrxnuvczXYUJCLQ0OZmwqpdbkhao*#MW&8%B@$'}, value=' .:-=+*#%@'),
#   'contrast': FloatSlider(value=1.2, description='Contraste', max=3.0, min=0.5),
#   'brightness': IntSlider(value=0, description='Brillo', max=50, min=-50),
#   'render_mode': RadioButtons(description='Modo', options=(('ASCII', 'ascii'), ('RAW (sin ASCII)', 'raw')), value='ascii'),
#   'raw_width': IntText(value=640, description='Raw W'),
#   'raw_height': IntText(value=360, description='Raw H'),
#   'raw_use_size': Checkbox(value=False, description='Usar tamano RAW'),
#   'frame_buffer_size': IntSlider(value=2, description='Buffer', max=3),
#   'bitrate': Text(value='1500k', description='Bitrate'),
#   'apply': Button(description='Aplicar ajustes', layout=Layout(width='140px'), style=ButtonStyle())},
#  'ia': {'face': Checkbox(value=False, description='Detección cara (face)'),
#   'hands': Checkbox(value=False, description='Detección manos (hands)'),
#   'pose': Checkbox(value=False, description='Detección pose (pose)'),
#   'viz': Dropdown(description='Visualización', options=('Normal (según ASCII/RAW)', 'Overlay landmarks'), value='Normal (según ASCII/RAW)'),
#   'apply': Button(description='Aplicar IA', layout=Layout(width='120px'), style=ButtonStyle()),
#   'detector_status': HTML(value='<i>Estado: — Pulsa «Actualizar estado detector» con el engine en marcha.</i>'),
#   'refresh_detector': Button(description='Actualizar estado detector', layout=Layout(width='200px'), style=ButtonStyle())},
#  'status': HTML(value='<div style="padding:8px 10px; background:#e7f1ff; border-radius:6px; margin:6px 0; border:1px solid #dee2e6; font-size:13px;">Sin filtros: imagen normal.</div>')}
# 10 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@466.060] global cap_v4l.cpp:804 requestBuffers VIDEOIO(V4L2:/dev/video2): failed VIDIOC_REQBUFS: errno=19 (No such device)
# [ WARN:20@467.068] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@467.070] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@467.084] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@467.120] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# 11 frames None consecutivos, intentando reabrir cámara...
# [ERROR:20@467.128] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@468.146] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@468.148] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@468.149] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@468.150] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@468.152] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 12 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@469.172] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@469.173] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@469.173] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@469.176] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@469.177] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 13 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@470.185] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@470.185] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@470.185] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@470.186] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@470.189] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 14 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@471.200] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@471.200] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@471.200] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@471.204] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@471.205] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 15 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@472.214] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@472.214] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@472.214] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@472.216] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@472.217] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 16 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@473.220] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@473.220] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@473.220] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@473.221] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@473.224] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 17 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@474.230] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@474.230] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@474.230] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@474.232] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@474.234] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 18 frames None consecutivos, intentando reabrir cámara...
# 19 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@475.242] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@475.242] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@475.242] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@475.243] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@475.245] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@476.252] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@476.252] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@476.252] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# 20 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@476.253] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@476.255] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 21 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@477.266] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@477.266] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@477.266] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@477.266] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@477.267] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@478.282] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@478.282] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@478.283] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@478.287] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@478.294] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 22 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@479.316] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@479.316] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@479.317] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@479.321] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@479.323] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 23 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@480.333] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@480.338] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@480.339] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@480.340] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@480.343] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 24 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@481.353] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@481.353] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@481.355] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@481.357] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@481.361] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 25 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@482.369] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@482.369] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@482.370] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@482.371] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@482.372] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 26 frames None consecutivos, intentando reabrir cámara...
# 27 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@483.394] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@483.394] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@483.394] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@483.396] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@483.397] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 28 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@484.406] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@484.407] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@484.407] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@484.407] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@484.408] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 29 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@485.416] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@485.416] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@485.416] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@485.416] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@485.417] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@486.424] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@486.425] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@486.425] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@486.427] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@486.428] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 30 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@487.435] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@487.435] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@487.436] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@487.437] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@487.440] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 31 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@488.458] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@488.460] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@488.460] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@488.461] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@488.462] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 32 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@489.469] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@489.470] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@489.470] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@489.473] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@489.475] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 33 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@490.484] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@490.484] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@490.485] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@490.485] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@490.486] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 34 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@491.501] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@491.501] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@491.502] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@491.503] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@491.504] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 35 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@492.512] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@492.512] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@492.513] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@492.513] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@492.514] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 36 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@493.518] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@493.518] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@493.518] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@493.519] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@493.520] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 37 frames None consecutivos, intentando reabrir cámara...
# 38 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@494.549] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@494.549] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@494.549] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@494.550] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@494.552] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@495.561] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@495.561] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@495.561] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@495.562] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@495.563] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 39 frames None consecutivos, intentando reabrir cámara...
# 40 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@496.582] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@496.582] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@496.582] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@496.582] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@496.584] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@497.593] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@497.594] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@497.595] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@497.596] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@497.597] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 41 frames None consecutivos, intentando reabrir cámara...
# 42 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@498.616] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@498.616] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@498.616] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@498.617] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@498.617] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@499.626] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@499.626] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@499.626] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@499.628] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@499.629] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 43 frames None consecutivos, intentando reabrir cámara...
# 44 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@500.665] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@500.665] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@500.665] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@500.665] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@500.666] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@501.684] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# 45 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@501.685] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@501.685] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@501.685] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@501.686] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@502.703] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@502.703] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@502.703] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@502.705] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@502.708] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 46 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@503.716] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@503.716] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@503.716] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@503.721] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@503.722] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 47 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@504.737] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@504.737] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# 48 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@504.741] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@504.742] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@504.743] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@505.755] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@505.755] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@505.759] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@505.760] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@505.761] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 49 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@506.774] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@506.774] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@506.776] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@506.778] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@506.781] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 50 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@507.784] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@507.784] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@507.784] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@507.790] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# ...
# 109 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@567.462] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@567.462] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@567.462] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@567.462] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@567.463] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 110 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@568.471] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@568.472] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@568.472] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@568.473] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# 111 frames None consecutivos, intentando reabrir cámara...
# [ERROR:20@568.478] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@569.481] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@569.483] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@569.483] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@569.485] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@569.486] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 112 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@570.491] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@570.492] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# 113 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@570.493] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@570.493] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@570.494] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:20@571.499] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@571.499] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@571.501] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@571.502] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@571.503] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 114 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@572.507] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@572.507] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@572.507] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@572.508] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@572.510] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 115 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@573.512] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@573.512] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@573.512] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@573.513] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@573.513] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 116 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@574.518] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@574.518] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@574.518] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@574.519] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@574.519] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 117 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@575.521] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@575.521] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@575.521] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@575.522] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@575.522] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 118 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@576.526] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@576.526] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@576.527] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@576.528] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@576.528] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 119 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@577.534] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@577.534] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@577.534] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@577.536] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@577.536] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 120 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@578.540] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@578.540] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@578.540] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@578.541] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@578.542] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 121 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@579.547] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@579.547] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@579.547] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@579.549] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@579.559] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 122 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@580.566] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@580.566] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@580.567] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@580.567] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@580.568] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 123 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@581.569] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@581.569] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@581.570] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@581.570] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@581.571] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 124 frames None consecutivos, intentando reabrir cámara...
# [ WARN:20@582.572] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@582.572] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:20@582.573] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:20@582.573] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:20@582.574] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 125 frames None consecutivos, intentando reabrir cámara...

# %%
# Diagnóstico: dispositivos, latencia, benchmark
build_diagnostics_panel(engine)
