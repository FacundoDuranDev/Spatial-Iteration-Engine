# %% [markdown]
# # Spatial Iteration Engine — Control completo en notebook
#
# Este notebook **genera el engine** y muestra **todo** en una sola sesión:
#
# 1. **Preview** — La cámara se ve en un widget de imagen debajo; no hace falta ventana de escritorio.
# 2. **Panel de control** — Pestañas: **Red**, **Engine** (Start/Stop, cámara), **Filtros** (Edges, Invert, Invert C++, etc.), **ASCII/RAW**, **IA** (detección cara/manos/pose, overlay landmarks).
# 3. **Diagnóstico** — Dispositivos de video, latencia y benchmarking.
#
# **Requisitos:** Jupyter desde la raíz del repo; `pip install ipywidgets`. Para IA (percepción): `bash cpp/build.sh` y `PYTHONPATH=python:cpp/build`.

# %%
import os
import sys

# Raíz del repo (ajusta si ejecutas desde otra ruta)
REPO_ROOT = "/home/fissure/repos/Spatial-Iteration-Engine"
os.chdir(REPO_ROOT)
if REPO_ROOT not in sys.path:
    sys.path.insert(0, os.path.join(REPO_ROOT, "python"))

print("Repo:", os.getcwd())
# Out:
# Repo: /home/fissure/repos/Spatial-Iteration-Engine

# %%
from python.ascii_stream_engine import (
    build_engine_for_notebook,
    build_general_control_panel,
    build_diagnostics_panel,
)

# Cámara 0; la imagen aparece debajo al pulsar Start
engine = build_engine_for_notebook(camera_index=0)

print("Engine creado. Usa el panel de abajo: pestaña Engine → Start.")
# Out:
# HTML(value='<b>Preview (la imagen aparece al pulsar Start)</b>')
# Image(value=b'', format='jpeg')
# Engine creado. Usa el panel de abajo: pestaña Engine → Start.

# %%
# Panel completo: Red, Engine, Filtros, ASCII/RAW, IA
build_general_control_panel(engine)
# Out:
# HTML(value='<b>Estado</b>')
# HTML(value='<div style="padding:8px 10px; background:#e7f1ff; border-radius:6px; margin:6px 0; border:1px soli…
# HTML(value='<b>Controles</b>')
# Tab(children=(VBox(children=(HTML(value='<b>Servidor en red</b>'), HTML(value='<small>Local = 127.0.0.1 · Broa…
# {'tabs': Tab(children=(VBox(children=(HTML(value='<b>Servidor en red</b>'), HTML(value='<small>Local = 127.0.0.1 · Broadcast/Multicast para UDP.</small>'), Dropdown(description='Modo red', options=('Local', 'Broadcast', 'Multicast', 'IP directa'), style=DescriptionStyle(description_width='80px'), value='Local'), HBox(children=(Text(value='127.0.0.1', description='Host', style=TextStyle(description_width='80px')), IntText(value=1234, description='Puerto', style=DescriptionStyle(description_width='80px')))), Button(description='Aplicar red', layout=Layout(width='120px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Motor</b>'), HTML(value='<small>Inicia para ver el preview en la celda de arriba.</small>'), HBox(children=(Button(description='▶ Iniciar', layout=Layout(width='100px'), style=ButtonStyle()), Button(description='■ Detener', layout=Layout(width='100px'), style=ButtonStyle()))), HTML(value='<b>Cámara</b>'), HBox(children=(IntText(value=0, description='Cámara', style=DescriptionStyle(description_width='80px')), Button(description='Aplicar cámara', layout=Layout(width='130px'), style=ButtonStyle())))), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Filtros de imagen</b>'), HTML(value='<small>Se aplican antes del render (ASCII/RAW). Puedes combinar varios.</small>'), HBox(children=(Checkbox(value=False, description='Edges'), Checkbox(value=False, description='Brightness/Contrast'), Checkbox(value=False, description='Invert'))), HBox(children=(Checkbox(value=False, description='Invert (C++)'), Checkbox(value=False, description='Detail Boost'))), Button(description='Quitar todos', layout=Layout(width='120px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Vista (ASCII / RAW)</b>'), HTML(value='<small>Video</small>'), IntSlider(value=20, description='FPS', max=60, min=10), HBox(children=(IntSlider(value=120, description='Grid W', max=200, min=60), IntSlider(value=60, description='Grid H', max=120, min=20))), HTML(value='<small>Apariencia</small>'), Dropdown(description='Charset', index=1, options={'Simple': ' .:-=+*#', 'Medio': ' .:-=+*#%@', 'Denso': ' .\'`^\\",:;Il!i~+_-?][}{1)(|\\\\/tfjrxnuvczXYUJCLQ0OZmwqpdbkhao*#MW&8%B@$'}, value=' .:-=+*#%@'), HBox(children=(FloatSlider(value=1.2, description='Contraste', max=3.0, min=0.5), IntSlider(value=0, description='Brillo', max=50, min=-50))), RadioButtons(description='Modo', options=(('ASCII', 'ascii'), ('RAW (sin ASCII)', 'raw')), value='ascii'), HTML(value='<small>RAW (tamaño)</small>'), HBox(children=(Checkbox(value=False, description='Usar tamano RAW'), IntText(value=640, description='Raw W'), IntText(value=360, description='Raw H'))), HBox(children=(IntSlider(value=2, description='Buffer', max=3), Text(value='1500k', description='Bitrate'))), Button(description='Aplicar ajustes', layout=Layout(width='140px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0')), VBox(children=(HTML(value='<b>Percepción (IA)</b>'), HTML(value='<div style="padding:6px; background:#f8f9fa; border-radius:4px; font-size:12px;">1) Activa cara/manos/pose · 2) Elige Overlay landmarks · 3) Aplicar IA · 4) Inicia el motor.</div>'), HBox(children=(Checkbox(value=False, description='Detección cara (face)'), Checkbox(value=False, description='Detección manos (hands)'), Checkbox(value=False, description='Detección pose (pose)'))), Dropdown(description='Visualización', options=('Normal (según ASCII/RAW)', 'Overlay landmarks'), value='Normal (según ASCII/RAW)'), Button(description='Aplicar IA', layout=Layout(width='120px'), style=ButtonStyle()), HTML(value='<b>Estado del detector</b>'), HTML(value='<i>Estado: — Pulsa «Actualizar estado detector» con el engine en marcha.</i>'), Button(description='Actualizar estado detector', layout=Layout(width='200px'), style=ButtonStyle())), layout=Layout(padding='0 0 10px 0'))), selected_index=0, titles=('Red', 'Motor', 'Filtros', 'Vista', 'IA')),
#  'network': {'mode': Dropdown(description='Modo red', options=('Local', 'Broadcast', 'Multicast', 'IP directa'), style=DescriptionStyle(description_width='80px'), value='Local'),
#   'host': Text(value='127.0.0.1', description='Host', style=TextStyle(description_width='80px')),
#   'port': IntText(value=1234, description='Puerto', style=DescriptionStyle(description_width='80px')),
#   'apply': Button(description='Aplicar red', layout=Layout(width='120px'), style=ButtonStyle())},
#  'engine': {'start': Button(description='▶ Iniciar', layout=Layout(width='100px'), style=ButtonStyle()),
#   'stop': Button(description='■ Detener', layout=Layout(width='100px'), style=ButtonStyle()),
#   'camera_index': IntText(value=0, description='Cámara', style=DescriptionStyle(description_width='80px')),
#   'apply_camera': Button(description='Aplicar cámara', layout=Layout(width='130px'), style=ButtonStyle())},
#  'filters': {'Edges': Checkbox(value=False, description='Edges'),
#   'Brightness/Contrast': Checkbox(value=False, description='Brightness/Contrast'),
#   'Invert': Checkbox(value=False, description='Invert'),
#   'Invert (C++)': Checkbox(value=False, description='Invert (C++)'),
#   'Detail Boost': Checkbox(value=False, description='Detail Boost')},
#  'ascii': {'fps': IntSlider(value=20, description='FPS', max=60, min=10),
#   'grid_w': IntSlider(value=120, description='Grid W', max=200, min=60),
#   'grid_h': IntSlider(value=60, description='Grid H', max=120, min=20),
#   'charset': Dropdown(description='Charset', index=1, options={'Simple': ' .:-=+*#', 'Medio': ' .:-=+*#%@', 'Denso': ' .\'`^\\",:;Il!i~+_-?][}{1)(|\\\\/tfjrxnuvczXYUJCLQ0OZmwqpdbkhao*#MW&8%B@$'}, value=' .:-=+*#%@'),
#   'contrast': FloatSlider(value=1.2, description='Contraste', max=3.0, min=0.5),
#   'brightness': IntSlider(value=0, description='Brillo', max=50, min=-50),
#   'render_mode': RadioButtons(description='Modo', options=(('ASCII', 'ascii'), ('RAW (sin ASCII)', 'raw')), value='ascii'),
#   'raw_width': IntText(value=640, description='Raw W'),
#   'raw_height': IntText(value=360, description='Raw H'),
#   'raw_use_size': Checkbox(value=False, description='Usar tamano RAW'),
#   'frame_buffer_size': IntSlider(value=2, description='Buffer', max=3),
#   'bitrate': Text(value='1500k', description='Bitrate'),
#   'apply': Button(description='Aplicar ajustes', layout=Layout(width='140px'), style=ButtonStyle())},
#  'ia': {'face': Checkbox(value=False, description='Detección cara (face)'),
#   'hands': Checkbox(value=False, description='Detección manos (hands)'),
#   'pose': Checkbox(value=False, description='Detección pose (pose)'),
#   'viz': Dropdown(description='Visualización', options=('Normal (según ASCII/RAW)', 'Overlay landmarks'), value='Normal (según ASCII/RAW)'),
#   'apply': Button(description='Aplicar IA', layout=Layout(width='120px'), style=ButtonStyle()),
#   'detector_status': HTML(value='<i>Estado: — Pulsa «Actualizar estado detector» con el engine en marcha.</i>'),
#   'refresh_detector': Button(description='Actualizar estado detector', layout=Layout(width='200px'), style=ButtonStyle())},
#  'status': HTML(value='<div style="padding:8px 10px; background:#e7f1ff; border-radius:6px; margin:6px 0; border:1px solid #dee2e6; font-size:13px;">Sin filtros: imagen normal.</div>')}
# [ WARN:11@43.384] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:11@43.384] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:11@43.385] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:11@43.395] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:11@43.397] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 10 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12@44.514] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@44.514] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@44.514] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@44.515] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@44.515] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 11 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12@45.517] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@45.517] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@45.517] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@45.518] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# 12 frames None consecutivos, intentando reabrir cámara...
# [ERROR:12@45.518] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:12@46.521] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@46.521] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@46.521] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@46.521] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@46.522] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 13 frames None consecutivos, intentando reabrir cámara...
# 14 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12@47.524] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@47.524] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@47.524] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@47.525] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@47.526] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:12@48.533] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@48.533] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@48.534] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@48.534] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@48.535] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 15 frames None consecutivos, intentando reabrir cámara...
# 16 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12@49.542] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@49.542] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@49.542] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@49.542] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@49.543] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:12@50.545] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@50.545] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@50.545] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@50.545] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@50.545] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 17 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12@51.548] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@51.548] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@51.549] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@51.549] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
# 18 frames None consecutivos, intentando reabrir cámara...
# [ERROR:12@51.550] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# [ WARN:12@52.551] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@52.551] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@52.552] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@52.552] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ERROR:12@52.552] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 19 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12@53.554] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@53.554] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@53.554] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [video4linux2,v4l2 @ 0x7f41500a2580] Cannot open video device /dev/video3: Permission denied
# [video4linux2,v4l2 @ 0x7f41500a2580] Cannot open video device /dev/video2: Permission denied
# [ WARN:12@53.555] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ WARN:12@53.556] global obsensor_stream_channel_v4l2.cpp:82 xioctl ioctl: fd=-1, req=-2140645888
# [ WARN:12@53.556] global obsensor_stream_channel_v4l2.cpp:138 queryUvcDeviceInfoList ioctl error return: 9
# [ WARN:12@53.556] global obsensor_stream_channel_v4l2.cpp:82 xioctl ioctl: fd=-1, req=-2140645888
# [ WARN:12@53.556] global obsensor_stream_channel_v4l2.cpp:138 queryUvcDeviceInfoList ioctl error return: 9
# [ERROR:12@53.556] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 20 frames None consecutivos, intentando reabrir cámara...
# 10 frames None consecutivos, intentando reabrir cámara...
# [ WARN:12
global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [ WARN:12@948.862] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:12@948.862] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video2): can't open camera by index
# [video4linux2,v4l2 @ 0x7f41500a2580] Cannot open video device /dev/video3: Permission denied
# [video4linux2,v4l2 @ 0x7f41500a2580] Cannot open video device /dev/video2: Permission denied
# [ WARN:12@948.863] global cap.cpp:438 open VIDEOIO(FFMPEG): raised OpenCV exception:
#
# OpenCV(4.13.0) /io/opencv/modules/videoio/src/cap_ffmpeg_impl.hpp:1220: error: (-2:Unspecified error) in function 'bool CvCapture_FFMPEG::open(const char*, int, const cv::Ptr<cv::IStreamReader>&, const cv::VideoCaptureParameters&)'
# > VIDEOIO/FFMPEG: Camera index out of range (expected: 'index < device_list->nb_devices'), where
# >     'index' is 2
# > must be less than
# >     'device_list->nb_devices' is 2
#
#
# [ WARN:12@948.864] global obsensor_stream_channel_v4l2.cpp:82 xioctl ioctl: fd=-1, req=-2140645888
# [ WARN:12@948.864] global obsensor_stream_channel_v4l2.cpp:138 queryUvcDeviceInfoList ioctl error return: 9
# [ WARN:12@948.864] global obsensor_stream_channel_v4l2.cpp:82 xioctl ioctl: fd=-1, req=-2140645888
# [ WARN:12@948.864] global obsensor_stream_channel_v4l2.cpp:138 queryUvcDeviceInfoList ioctl error return: 9
# [ERROR:12@948.864] global obsensor_uvc_stream_channel.cpp:163 getStreamChannelGroup Camera index out of range
# 337 frames None consecutivos, intentando reabrir cámara...

# %%
# Diagnóstico: dispositivos, latencia, benchmark
build_diagnostics_panel(engine)
# Out:
# [ WARN:0@2.773] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video1): can't open camera by index
# [ WARN:0@2.773] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:0@3.731] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video3): can't open camera by index
# [ WARN:0@3.731] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:0@3.732] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video4): can't open camera by index
# [ WARN:0@3.732] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# [ WARN:0@3.732] global cap_v4l.cpp:914 open VIDEOIO(V4L2:/dev/video5): can't open camera by index
# [ WARN:0@3.732] global cap.cpp:478 open VIDEOIO(V4L2): backend is generally available but can't be used to capture by index
# VBox(children=(HTML(value='<h3>Diagnóstico y benchmarking</h3>'), VBox(children=(HTML(value='<b>Dispositivos c…
# {'panel': VBox(children=(HTML(value='<h3>Diagnóstico y benchmarking</h3>'), VBox(children=(HTML(value='<b>Dispositivos conectados</b>'), HTML(value='<pre><b>Dispositivos de video</b>\n  /dev/video0 (modo 660)\n  /dev/video1 (modo 660)\n  /dev/video2 (modo 660)\n  /dev/video3 (modo 660)\n<br><b>Grupo video</b>: sí\n  groups: video adm dialout fax cdrom floppy tape sudo audio dip plugdev users netdev bluetooth wireshark scanner kaboxer libvirt docker sambashare kvm input fissure\n<br><b>OpenCV</b> 4.13.0\n  índice 0: ABRE shape=(480, 640, 3)\n  índice 2: ABRE shape=(480, 640, 3)\n  backend: V4L2</pre>'), Button(description='Actualizar', style=ButtonStyle()))), HTML(value='<br>'), VBox(children=(HTML(value='<b>Latencia del proceso</b>'), HTML(value='<i>Inicia el engine para ver latencia en tiempo real.</i>'), HTML(value='<small>Pulsa Actualizar con el engine en marcha para refrescar.</small>'))), HTML(value='<br>'), VBox(children=(HTML(value='<b>Benchmarking</b>'), HBox(children=(IntText(value=5, description='Segundos'), HTML(value='s'))), Button(description='Ejecutar benchmark', style=ButtonStyle()), Output())))),
#  'devices_html': HTML(value='<pre><b>Dispositivos de video</b>\n  /dev/video0 (modo 660)\n  /dev/video1 (modo 660)\n  /dev/video2 (modo 660)\n  /dev/video3 (modo 660)\n<br><b>Grupo video</b>: sí\n  groups: video adm dialout fax cdrom floppy tape sudo audio dip plugdev users netdev bluetooth wireshark scanner kaboxer libvirt docker sambashare kvm input fissure\n<br><b>OpenCV</b> 4.13.0\n  índice 0: ABRE shape=(480, 640, 3)\n  índice 2: ABRE shape=(480, 640, 3)\n  backend: V4L2</pre>'),
#  'latency_html': HTML(value='<i>Inicia el engine para ver latencia en tiempo real.</i>'),
#  'refresh_btn': Button(description='Actualizar', style=ButtonStyle()),
#  'benchmark_btn': Button(description='Ejecutar benchmark', style=ButtonStyle()),
#  'benchmark_output': Output(),
#  'refresh': <function python.ascii_stream_engine.presentation.notebook_api.build_diagnostics_panel.<locals>.refresh(_=None) -> None>}
